# %% [markdown]
# # Métodos Numéricos para Equações Diferenciais II – 2023/2

# %% [markdown]
# **Aluno:** Matheus de Costa Harduim.
#
# **Professor:** Grazione de Souza.
#
# **Instituição:** UERJ – IPRJ – DMC

# %% [markdown]
# ### Desenvolvimento dos códigos e comentários.

# %% [markdown]
# Importando as bibliotecas do python que serão utilizadas

# %%
import numpy.matlib
import numpy as np
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import optimize

# %% [markdown]
# # Trabalho 1

# %% [markdown]
# ## Dados do problema
# - $u = 0.25$
# - $ \alpha = 0,1$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = 5$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = 1/2$

# %% [markdown]
# Inicializando a variáveis

# %%
u = 0.25
alpha = 0.1
ca = 1.0
cb = 0.0
lX = 10.0
tTotal = 5
deltX = 0.05
porcAvan = 1/2
# percentual de como os volumes estam preenchidos

# %%
def metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan):
    # definicao do numero de volumes
    nx = int(lX/deltX)
    print(f'numero de volumes: {nx}')
    # definicao deltaT e passos de tempo
    # Considerando a condição de tempo do qual o método é estável
    deltT = 1 /((u/deltX) + (2*alpha/(deltX**2)))
    n = int(tTotal/deltT)
    print(f'valor passo de tempo deltaT: {deltT}')
    print(f'numero de passos de tempo: {n}')
    # inicializando o vetor considerando as condicoes de contorno
    qInit = []
    for i in range(nx):
        if i < int(nx*porcAvan):
            qInit.append(ca)
        if i >= int(nx*porcAvan):
            qInit.append(cb)
    # inicia o c iterativo
    #---------------------
    cItr = ca
    qFinal = qInit
    espaco = [0.0]
    for k in range(nx-1):
        espaco.append(espaco[k] + deltX)
    for i in range(n):
        qItr = []
        #-----------------
        #definição de mudança de vazão
        if i >= n/2:
            cItr = ca*1.2
        q0 = 2*cItr - qFinal[0]
        for j in range(nx):
            if j == 0:
                qItr.append(
                    qFinal[j] - (deltT/deltX)*
                    (u*(qFinal[j]-q0)-alpha*((qFinal[j+1]-2*qFinal[j]+q0)/deltX)))
            elif j == nx-1:
                qItr.append(qFinal[j] - (deltT/deltX)*
                            (u*(qFinal[j]-qFinal[j-1])-alpha*((qFinal[j]-2*qFinal[j]+qFinal[j-1])/deltX)))
            else:
                qItr.append(qFinal[j] - (deltT/deltX)*
                            (u*(qFinal[j]-qFinal[j-1])-alpha*((qFinal[j+1]-2*qFinal[j]+qFinal[j-1])/deltX)))
        qFinal = qItr
    return espaco, qFinal

# %%
x, Qs = metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan)
# Out:
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424

# %%
plt.figure()
plt.title(f'Grafico equação de adveccao-difucao')
plt.plot(x,Qs)
plt.xlabel('X')
plt.ylabel('C')
plt.grid()
plt.show()

# %% [markdown]
# ## Teste variação da velocidade de advecção
# - $u = varia$
# - $ \alpha = 0,1$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = 5$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = 1/2$

# %%
us = 0.25*np.array([0.0,0.6,0.8,1.0,1.2,1.4])
alpha = 0.1
ca = 1.0
cb = 0.0
lX = 10.0
tTotal = 5
deltX = 0.05
porcAvan = 1/2
# percentual de como os volumes estam preenchidos

# %%
QsItr = []
xItr = []
for u in us:
    x, Qs = metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan)
    xItr = x
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['y','g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando u)')
for u in us:
    plt.plot(xItr,QsItr[i], color = colors[i])
    i+=1
plt.xlabel('X')
plt.ylabel('C')
plt.grid()
plt.show()
# Out:
# numero de volumes: 200
# valor passo de tempo deltaT: 0.012500000000000002
# numero de passos de tempo: 399
# numero de volumes: 200
# valor passo de tempo deltaT: 0.01204819277108434
# numero de passos de tempo: 414
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011904761904761908
# numero de passos de tempo: 419
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011627906976744188
# numero de passos de tempo: 429
# numero de volumes: 200
# valor passo de tempo deltaT: 0.01149425287356322
# numero de passos de tempo: 434

# %% [markdown]
# ## Teste variação do termo de difusão
# - $u = 0,25$
# - $ \alpha = varia$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = 5$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = 1/2$

# %%
u = 0.25
alphas = 0.1*np.array([0.0,0.6,0.8,1.0,1.2,1.4])
ca = 1.0
cb = 0.0
lX = 10.0
tTotal = 5
deltX = 0.05
porcAvan = 1/2
# percentual de como os volumes estam preenchidos

# %%
QsItr = []
xItr = []
for alpha in alphas:
    x, Qs = metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan)
    xItr = x
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['y','g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando alpha)')
for alpha in alphas:
    plt.plot(xItr,QsItr[i], color = colors[i])
    i+=1
plt.xlabel('X')
plt.ylabel('C')
plt.grid()
plt.show()
# Out:
# numero de volumes: 200
# valor passo de tempo deltaT: 0.2
# numero de passos de tempo: 25
# numero de volumes: 200
# valor passo de tempo deltaT: 0.018867924528301893
# numero de passos de tempo: 264
# numero de volumes: 200
# valor passo de tempo deltaT: 0.014492753623188406
# numero de passos de tempo: 345
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.009900990099009905
# numero de passos de tempo: 504
# numero de volumes: 200
# valor passo de tempo deltaT: 0.00854700854700855
# numero de passos de tempo: 584

# %% [markdown]
# ## Teste variação do Lx
# - $u = 0,25$
# - $ \alpha = varia$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = varia$
# - ${t}_{total} = 5$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = 1/2$

# %%
u = 0.25
alpha = 0.1
ca = 1.0
cb = 0.0
lXs = 10.0*np.array([0.6,0.8,1.0,1.2,1.4])
tTotal = 5
deltX = 0.05
porcAvan = 1/2
# percentual de como os volumes estam preenchidos

# %%
QsItr = []
xItr = []
for lX in lXs:
    x, Qs = metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan)
    xItr.append(x)
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando Lx)')

for lX in lXs:
    plt.plot(xItr[i],QsItr[i], color = colors[i])
    plt.xlabel('X')
    plt.ylabel('C')
    plt.grid()
    plt.show()
    i+=1
# Out:
# numero de volumes: 120
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 160
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 240
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 280
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424

# %% [markdown]
# ## Teste variação do tempo totalX
# - $u = 0,25$
# - $ \alpha = 0,1$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = varia$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = 1/2$

# %%
u = 0.25
alpha = 0.1
ca = 1.0
cb = 0.0
lX = 10.0
tTotals = 5*np.array([0.6,0.8,1.0,1.2,1.4])
deltX = 0.05
porcAvan = 1/2
# percentual de como os volumes estam preenchidos

# %%
QsItr = []
xItr = []
for tTotal in tTotals:
    x, Qs = metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan)
    xItr = x
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['y','g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando tempo total)')
for tTotal in tTotals:
    plt.plot(xItr,QsItr[i], color = colors[i])
    i+=1
plt.xlabel('X')
plt.ylabel('C')
plt.grid()
plt.show()
# Out:
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 254
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 339
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 509
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 594

# %% [markdown]
# ## Teste variação de deltaX
# - $u = 0,25$
# - $ \alpha = 0,1$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = 5$
# - $\Delta x = varia$
# - $\%\ de\ avanço = 1/2$

# %%
u = 0.25
alpha = 0.1
ca = 1.0
cb = 0.0
lXs = 10.0
tTotal = 5
deltXs = 0.05*np.array([0.6,0.8,1.0,1.2,1.4])
porcAvan = 1/2
# percentual de como os volumes estam preenchidos

# %%
QsItr = []
xItr = []
for deltX in deltXs:
    x, Qs = metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan)
    xItr.append(x)
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando deltaX)')

for deltX in deltXs:
    plt.plot(xItr[i],QsItr[i], color = colors[i])
    plt.xlabel('X')
    plt.ylabel('C')
    plt.grid()
    plt.show()
    i+=1
# Out:
# numero de volumes: 333
# valor passo de tempo deltaT: 0.004337349397590362
# numero de passos de tempo: 1152
# numero de volumes: 249
# valor passo de tempo deltaT: 0.0076190476190476225
# numero de passos de tempo: 656
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 166
# valor passo de tempo deltaT: 0.01674418604651163
# numero de passos de tempo: 298
# numero de volumes: 142
# valor passo de tempo deltaT: 0.022528735632183904
# numero de passos de tempo: 221

# %% [markdown]
# ## Teste variação da porcentagem de avanço
# - $u = 0,25$
# - $ \alpha = 0,1$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = 5$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = varia$

# %%
u = 0.25
alpha = 0.1
ca = 1.0
cb = 0.0
lXs = 10.0
tTotal = 5
deltX = 0.05
porcAvans = 1/2*np.array([0.6,0.8,1.0,1.2,1.4])
# percentual de como os volumes estam preenchidos

# %%
QsItr = []
xItr = []
for porcAvan in porcAvans:
    x, Qs = metodoEx(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan)
    xItr = x
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando porcentagem de avanço)')
for porcAvan in porcAvans:
    plt.plot(xItr,QsItr[i], color = colors[i])
    i+=1
plt.xlabel('X')
plt.ylabel('C')
plt.grid()
plt.show()
# Out:
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424

# %% [markdown]
# ## Testes de variação específica do código

# %% [markdown]
# ### Teste de variação da vazão de Injeção
# - $u = 0,25$
# - $ \alpha = 0,1$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = 5$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = 1/2$
# - $cItr = varia$

# %%
u = 0.25
alpha = 0.1
ca = 1.0
cb = 0.0
lXs = 10.0
tTotal = 5
deltX = 0.05
porcAvans = 1/2
cInjItrs = 1.2*np.array([0.6,0.8,1.0,1.2,1.4])
# percentual de como os volumes estam preenchidos

# %%
def metodoExManipulado(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan, cItr):
    # definicao do numero de volumes
    nx = int(lX/deltX)
    print(f'numero de volumes: {nx}')
    # definicao deltaT e passos de tempo
    # Considerando a condição de tempo do qual o método é estável
    deltT = 1 /((u/deltX) + (2*alpha/(deltX**2)))
    n = int(tTotal/deltT)
    print(f'valor passo de tempo deltaT: {deltT}')
    print(f'numero de passos de tempo: {n}')
    # inicializando o vetor considerando as condicoes de contorno
    qInit = []
    for i in range(nx):
        if i < int(nx*porcAvan):
            qInit.append(ca)
        if i >= int(nx*porcAvan):
            qInit.append(cb)
    # inicia o c iterativo
    #---------------------
    cItr = ca
    qFinal = qInit
    espaco = [0.0]
    for k in range(nx-1):
        espaco.append(espaco[k] + deltX)
    for i in range(n):
        qItr = []
        #-----------------
        #definição de mudança de vazão
        if i >= n/2:
            cItr = ca*cInjItr
        q0 = 2*cItr - qFinal[0]
        for j in range(nx):
            if j == 0:
                qItr.append(
                    qFinal[j] - (deltT/deltX)*
                    (u*(qFinal[j]-q0)-alpha*((qFinal[j+1]-2*qFinal[j]+q0)/deltX)))
            elif j == nx-1:
                qItr.append(qFinal[j] - (deltT/deltX)*
                            (u*(qFinal[j]-qFinal[j-1])-alpha*((qFinal[j]-2*qFinal[j]+qFinal[j-1])/deltX)))
            else:
                qItr.append(qFinal[j] - (deltT/deltX)*
                            (u*(qFinal[j]-qFinal[j-1])-alpha*((qFinal[j+1]-2*qFinal[j]+qFinal[j-1])/deltX)))
        qFinal = qItr
    return espaco, qFinal

# %%
QsItr = []
xItr = []
for cInjItr in cInjItrs:
    x, Qs = metodoExManipulado(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan, cInjItr)
    xItr = x
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando a vazão de injeção)')
for cInjItr in cInjItrs:
    plt.plot(xItr,QsItr[i], color = colors[i])
    i+=1
plt.xlabel('X')
plt.ylabel('C')
plt.grid()
plt.show()
# Out:
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424
# numero de volumes: 200
# valor passo de tempo deltaT: 0.011764705882352943
# numero de passos de tempo: 424

# %% [markdown]
# ### Teste de variação de deltaT forçados
# - $u = 0,25$
# - $ \alpha = 0,1$
# - ${C}_{A} = 1,0 $
# - ${C}_{B} = 0,0 $
# - ${L}_{x} = 10m$
# - ${t}_{total} = 5$
# - $\Delta x = 0,05$
# - $\%\ de\ avanço = 1/2$
# - $\Delta t = 0,012$

# %%
u = 0.25
alpha = 0.1
ca = 1.0
cb = 0.0
lXs = 10.0
tTotal = 5
deltX = 0.05
porcAvans = 1/2
deltTs = 0.0116*np.array([0.8,1.0,1.2])
# percentual de como os volumes estam preenchidos

# %%
def metodoExManipulado(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan, deltT):
    # definicao do numero de volumes
    nx = int(lX/deltX)
    print(f'numero de volumes: {nx}')
    n = int(tTotal/deltT)
    print(f'valor passo de tempo deltaT: {deltT}')
    print(f'numero de passos de tempo: {n}')
    # inicializando o vetor considerando as condicoes de contorno
    qInit = []
    for i in range(nx):
        if i < int(nx*porcAvan):
            qInit.append(ca)
        if i >= int(nx*porcAvan):
            qInit.append(cb)
    # inicia o c iterativo
    #---------------------
    cItr = ca
    qFinal = qInit
    espaco = [0.0]
    for k in range(nx-1):
        espaco.append(espaco[k] + deltX)
    for i in range(n):
        qItr = []
        #-----------------
        #definição de mudança de vazão
        if i >= n/2:
            cItr = ca*1.2
        q0 = 2*cItr - qFinal[0]
        for j in range(nx):
            if j == 0:
                qItr.append(
                    qFinal[j] - (deltT/deltX)*
                    (u*(qFinal[j]-q0)-alpha*((qFinal[j+1]-2*qFinal[j]+q0)/deltX)))
            elif j == nx-1:
                qItr.append(qFinal[j] - (deltT/deltX)*
                            (u*(qFinal[j]-qFinal[j-1])-alpha*((qFinal[j]-2*qFinal[j]+qFinal[j-1])/deltX)))
            else:
                qItr.append(qFinal[j] - (deltT/deltX)*
                            (u*(qFinal[j]-qFinal[j-1])-alpha*((qFinal[j+1]-2*qFinal[j]+qFinal[j-1])/deltX)))
        qFinal = qItr
    return espaco, qFinal

# %%
QsItr = []
xItr = []
for deltT in deltTs:
    x, Qs = metodoExManipulado(u,alpha,ca,cb,lX,tTotal,deltX,porcAvan, deltT)
    xItr.append(x)
    QsItr.append(Qs)
    
i = 0
plt.figure()
colors = ['g','r','k','b','c']
plt.title(f'Adveccao-difucao (variando o deltT)')
for deltT in deltTs:
    plt.plot(xItr[i],QsItr[i], color = colors[i])
    i+=1
    plt.xlabel('X')
    plt.ylabel('C')
    plt.grid()
    plt.show()
# Out:
# numero de volumes: 200
# valor passo de tempo deltaT: 0.00928
# numero de passos de tempo: 538
# numero de volumes: 200
# valor passo de tempo deltaT: 0.0116
# numero de passos de tempo: 431
# numero de volumes: 200
# valor passo de tempo deltaT: 0.013919999999999998
# numero de passos de tempo: 359

# %% [markdown]
# # Trabalho 2
